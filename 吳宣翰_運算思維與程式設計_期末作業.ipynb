# %% [markdown]
# <a href="https://colab.research.google.com/github/a109010025/Computational-Thinking-and-Program-Design/blob/main/%E5%90%B3%E5%AE%A3%E7%BF%B0_%E9%81%8B%E7%AE%97%E6%80%9D%E7%B6%AD%E8%88%87%E7%A8%8B%E5%BC%8F%E8%A8%AD%E8%A8%88_%E6%9C%9F%E6%9C%AB%E4%BD%9C%E6%A5%AD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #開頭
# 一大清早，西銘市警察局的王警探就因為各種大大小小的事忙的焦頭爛額
#
# 好不容易忙到一段落
# >
# 已經接近正中午時
#
# >
# 正當他以為總算可以休息時
# >
# **一個陌生號碼打進了他的手機...**
#
# ------------------------------------------------------------------------------
# 「喂，我是王警探。」 王警探用略帶不耐煩的語氣自我介紹
# >
# 「你好，王警探，你不必知道我是誰，你只要知道我已經在西銘摩天大樓安裝了炸彈就好。」
# >
# 電話那頭的人聲音文雅且冷靜
# >
# 但王警探多年的工作經驗告訴他
# >
# **這個人並沒有在開玩笑**
# >
# 電話那頭的人停頓了一下
# >
# 繼續說道：
# >
# 「你或許不會相信我說的話，**因此我將會引爆第一顆炸彈來證明**。」
#
#
# ---
# >
# 語畢
# >
# 王警探便聽到不遠處傳來巨大的爆炸聲
# >
# **證明這名炸彈犯所言不假**
# >
# 王警探嚥了口口水，穩定自己震驚的心情
# >
# 繼續聽對方的話
# >
# 「你不用擔心，這顆炸彈是在停車場引爆的，我已經確定停車場裡沒有任何人，但我已經扣押了9名人質，若你不早點趕過來的話，等到大樓裡的炸彈爆炸後，我就不保證這九個人能不能活下來了。」
# >
# 「你想要的到底是什麼！？」王警探透過電話質問對方。
# >
# 「我要你在半小時內單獨來這裡，而且不准穿任何防爆衣，我會在頂樓等你，若你沒有照我的要求，這棟大樓裡的所有人都會沒命。」
# >
# 炸彈客就掛斷了電話，不讓王警探有更多的詢問機會
# >
# 王警探別無選擇
# >
# 披上了外套，駕車前往西銘大樓。
#
#
# ---
#
#
# ------------------------------------------------------------------------------

# %% [markdown]
# 王警探一到達西銘大樓，炸彈客立刻打了過來。
# >
# 「王警探，歡迎你來到這裡，接下來，我將會為你解釋遊戲規則。」
# >
# 「遊戲？」王警探反問。
# >
# 「沒錯，是益智問答，若你能成功答對
# >
# 你將能救出這些人質。
# >
# 我在**一樓、40樓跟頂樓**都各放了**3個人質**
# >
# 每個人質的脖子上都戴上了微型炸彈項鍊
# >
# 題目就寫在脖子後面，人質會輪流出來讓你看題目，你必須答對該題，該人質的項鍊才能拆下來
# >
# 若答錯
# >
# **炸彈的威力並不會傷到你，但這名人質的脖子就會在你眼前爆炸。」**
# >
# >
# 「你這個神經病！」王警探咬牙切齒的罵道
# >
# 但對方並沒有理會，而是繼續講解規則。
# >
# 「另外，你**每個樓層都需要答對至少兩題以上**，若你只答對一題，甚至是根本沒有答對的話，我便會引爆在大樓內剩餘的炸彈，讓你連答題的機會都沒有，這樣你理解了嗎？」
# >
# 王警探深知沒有跟對方談判的餘地，只好提起勇氣，掛斷電話後走進大樓。
#
#
# ---

# %%
print("(早上八點，西銘市警察局的王警探已經在工作崗位上。")
print("(桌上已經堆滿許多待處理案件。)")
print("王警探 : 今天依舊忙碌的一天，算了先來想要喝什麼來開啟美好的一天。")
drink = input("Enter your choice:")
print("王警探 : 好耶!就決定喝", drink ,"了!")
print("(早上的警局非常忙碌，各警員各司其職。)")
print("(不知不覺到了中午。)")
print("王警探 : 上午處理的事情也太多了吧!快累死了，肚子好餓。")
print("王警探 : 中午要吃什麼呢?炒飯還是義大利麵，想一下吃什麼下午比較有精神。")
lunch = input("午餐吃炒飯還是義大利麵:")
if lunch == "炒飯":
    print("王警探 : 吃炒飯好了!雖然那裡很髒但是超好吃!")
if lunch == "義大利麵":
    print("王警探 : 今天這麼累，好好犒賞自己吃點好的!")
print("(拎拎拎!)")
print("王警探 : 唉呀!怎麼這時候剛好有電話進來。")
print("(王警探不耐煩的接起電話。)")
print("王警探: 您好，這裡是西銘市警察局。")
print("神秘人士 : 您好，不必知道我是誰，只要知道我在西銘摩天大樓安裝炸彈就好。")
print("(面對突如其來的告知，王警探一時反應不過來。)")
print("王警探 : 怎麼感覺是來亂的?到底要接案還是掛掉電話?")
choice = input("請選擇接案或是掛掉電話:")
if choice == "接案":
    print("神秘人士 : 你或許不會相信我說的話，因此我將會引爆第一顆炸彈來證明。")
    print("(蹦!!!)")
    print("(遠方傳來爆炸聲)")
    print("王警探 : 這...這到底是怎樣?")
    print("你不用擔心，這顆炸彈是在停車場引爆的，我已經確定停車場裡沒有任何人，但我已經扣押了9名人質，若你不早點趕過來的話，等到大樓裡的炸彈爆炸後，我就不保證這9個人能不能活下來了。")
    print("(這時王警探發現，他就是傳說中的神祕炸彈客。)")
    print("你想要的到底是什麼!?")
    print("炸彈客 : 我要你在半小時內單獨來這裡，而且不准穿任何防爆衣，我會在頂樓等你，若你沒有照我的要求，這棟大樓裡的所有人都會沒命。")
    print("王警探 : 等...等等...")
    print("(炸彈客掛斷電話，不讓王警探有更多的詢問機會。)")
    print("王警探 : 唉，看來得單刀去了，但怕我會死在那裏，我該穿防爆衣嗎?")
    explosive_proof = input("Yes or No:")
    print("王警探 : 必須要在半小時內達到大樓，以全程最高速度駕駛為前提，自駕汽車最高可以開到60km/hr，加上等交通號誌時間6分鐘 ; 機車最高可以騎到30km/hr，但機動性高可以鑽小路，可省去12分鐘。")
    vehicle = input("請選擇汽車還是機車:")
    if explosive_proof == "No" and vehicle == "機車":
        print("(王警探一到達西銘大樓，炸彈客立刻打了過來。)")
        print("炸彈客 : 王警探，歡迎你來到這裡，接下來，我將會為你解釋遊戲規則。")
        print("王警探 : 遊戲?")
        print("炸彈客 : 沒錯，是益智問答，若你能成功答對，你將能救出這些人質。")
        print("炸彈客 : 我在一樓、40樓跟頂樓都各放了3個人質，每個人質的脖子上都戴上了微型炸彈項鍊。題目就寫在脖子後面，人質會輪流出來讓你看題目，你必須答對該題，該人質的項鍊才能拆下來")
        print("炸彈客 :　不過若答錯，也別擔心炸彈的威力會傷到你，這名人質的脖子就會在你眼前爆炸。")
        print("王警官 : 你這個神經病!")
        print("(炸彈客並未理會王警官，王警官發現他情緒異常穩定。)")
        print("炸彈客 : 另外，你每個樓層都需要答對至少兩題以上，若你只答對一題，甚至是根本沒有答對的話，我便會引爆在大樓內剩餘的炸彈，讓你連答題的機會都沒有，這樣你理解了嗎？")
        print("老實點，你做什麼事情我都會知道。")
        print("(王警探深知沒有跟對方談判的餘地，只好提起勇氣，掛斷電話後走進大樓。)")
        print("                           ")
        print("-----------------------------------------------------------------------")
        print("                           ")
        print('一進到大樓，你便看到三名人質顫抖著')
        print('站在服務台前，他們的脖子上都戴著一條鐵色的項圈，上面有紅光緩緩的在閃爍......')
        print('這時，大樓內的廣播響了起來：')
        print('                          ')
        print('*「那麼，第一位人質請上前。」*')
        print('站在最左側的人質走了向前.')
        print('是位中年婦女')
        print('她用顫抖的聲音哀求著王警探，希望王警探能趕緊讓她脫離恐懼。')
        print('                          ')
        print('王警探觀察了她的脖子後面')
        print('上面寫著一個題目以及三個選項')
        print('選項分別代表著紅色、藍色及白色')
        print('而項圈上也有這三個顏色的引線')
        print('王警探必須選擇正確的顏色剪斷，而機會只有一次。')
        print('                          ')
        print('Q1:「鱟」在生物學上的分類？')
        print('1.節肢動物門 2.腔腸動物門 3.軟體動物門')
        ans1=int(input('輸入你的答案:'))
        if ans1 == 1:
          print('恭喜你答對了～ 沒想到竟然被你輕鬆答對')
          print('「讓我們歡迎第二名人質。」廣播聲再次響起。')
          print('                           ')
          print('-----------------------------------------------------------------------')
          print('第二名人質拖著有氣無力的腳步走向王警探')
          print('「拜託你了。」他望向王警探的眼神中沒有任何的希望。')
          print('                           ')
          print('Q2:日本名著的明治神宮，位於？')
          print('1.山形 2.東京 3.大阪')
          ans2=int(input('輸入你的答案:'))
          if ans2 == 2:
            print('竟然又被你猜對了... 接下來可沒那麼容易')
            print('                           ')
            print('「接下來，是第三名人質。」廣播聲再次響起。')
            print('第三名人質是位壯年男子')
            print('他拍了拍王警探的背，用激勵的眼神看著王警探')
            print('「我相信你。」短短的四個字，給了王警探巨大的信心。')
            print('                           ')
            print('Q3:歌劇「費加洛婚禮」為何者作品？')
            print('1.莫札特 2.小柴可夫斯基 3.普契尼')
            ans3=int(input('輸入你的答案:'))
            if ans3 == 1:
              print('                           ')
              print('呵呵呵 真有趣.....')

              print('                           ')
              print('-----------------------------------------------------------------------')
              print('王警探乘坐著電梯來到了40樓')
              print('電梯門一開，他便看到了跟一樓相似的場景')
              print('                           ')
              print('三名無辜的人質、以及他們脖子上那危險的殺人工具。')
              print('                           ')
              print('「歡迎來到40樓，王警探，我佩服你的勇氣。」')
              print('廣播裡再度傳來炸彈犯那冷靜且無情的聲音。')
              print('                           ')
              print('-----------------------------------------------------------------------')
              print('「第四名人質，請上前。」')
              print('                           ')
              print('宛如被宣告死刑一般，站在最左邊的大樓職員露出了驚恐的表情，走上前面對自己的生死')
              print('他萬萬沒想到，他跟平常一樣的來這裡上班，卻會碰上這種事。')
              print('                           ')
              print('Q4:已知果蠅體細胞內有四對染色體，則其卵子中的染色體數？')
              print('1.四對染色體 2.兩對染色體 3.兩條不成對染色體')
              ans4=int(input('輸入你的答案:'))
              if ans4 == 2:
                print('                           ')
                print('「又對了...」')
                print('「一開始選上你真是正確的選擇啊  太有趣了....」')
                print('                           ')
                print('-----------------------------------------------------------------------')
                print('「輪到你了，小朋友。」廣播裡的聲音沒有任何的改變')
                print('                           ')
                print('第五名人質是一位小男孩')
                print('目測年齡大概只有10歲左右')
                print('但犯人並不會因此放過他。')
                print('                           ')
                print('但小男孩卻因為害怕，沒有任何的行動')
                print('王警探只好走到小男孩的背後來看題目，並抓著小男孩的手，給小男孩勇氣。')
                print('                           ')
                print('                           ')
                print('Q5:唐朝詩人，善有長恨歌描寫楊貴妃生平的是？')
                print('1.張繼 2.杜光庭 3.白居易')
                ans5=int(input('輸入你的答案:'))
                if ans5 == 3:
                  print('                           ')
                  print('「呵......」')
                  print('                           ')
                  print('-----------------------------------------------------------------------')
                  print('第六名人質對王警探的壓力是目前為止最大的')
                  print('                           ')
                  print('因為第六名人質是名孕婦')
                  print('                           ')
                  print('代表著王警探這一次的選擇，將背負著兩條人命。')
                  print('                           ')
                  print('孕婦走向王警探時，並沒有說任何話')
                  print('甚至連眼神都沒有交會')
                  print('孕婦只是轉過身，撩起頭髮，讓王警探看清楚題目。')
                  print('                           ')
                  print('Q6:創立坐標幾何的人是誰？')
                  print('1.巴比 2.笛卡兒 3.畢達哥拉斯')
                  ans6=int(input('輸入你的答案:'))
                  if ans6 == 2:
                    print('                           ')
                    print('「哈哈哈哈哈.哈..哈.哈....」  犯人此時漸漸感受到不妙')
                    print('                           ')

                    print('                           ')
                    print('-----------------------------------------------------------------------')
                    
                    print('西銘大樓的頂樓並沒有辦法直接搭電梯上去，而是必須走樓梯')
                    print('因此王警探搭到電梯能到的最高樓後，便往樓梯間奔去')
                    print('                           ')
                    print('往上沒多久，在到達頂樓前的樓梯上遇到了三名人質')
                    print('而人質的背後，就是炸彈犯。')
                    print('                           ')
                    print('炸彈犯穿的西裝筆挺，戴著面具，整個人的氣質就跟他的聲音一樣：彬彬有禮，卻又令人不寒而慄。')
                    print('                           ')
                    print('-----------------------------------------------------------------------')
                    print('                           ')
                    print('「很高興見到你，王警探，總算不用透過廣播或電話給你溝通了。」炸彈犯笑著說。')
                    print('                           ')
                    print('王警探恨不得直接衝上去給對方一拳')
                    print('但對方手上還有三名人質，王警探只能忍住怒氣，繼續遵照對方的規則走。')
                    print('                           ')
                    print('-----------------------------------------------------------------------')
                    print('沒有等炸彈犯催促，第七名人質便自動走了上前')
                    print('是位目測四十歲左右的女性')
                    print('胸前的名牌表示了她是這棟大樓的主管之一。')
                    print('                           ')
                    print('Q7:俗稱的安息香油是？')
                    print('1.乙烯 2.甲烷 3.苯')
                    ans7=int(input('輸入你的答案:'))
                    if ans7 == 3:
                      print('                           ')
                      print('「什...什..什麼！」')
                      print('                           ')
                      print('-----------------------------------------------------------------------')
                      print('第八名人質是名小混混')
                      print('用面帶不屑的眼神撇了一眼炸彈犯後')
                      print('搖晃著身體，慢慢的走向王警探')
                      print('但王警探看得出來，他只是在逞兇鬥狠。')
                      print('                         ')
                      print('Q8:「但願人長久，千里共嬋娟。」出自蘇軾的何首作品？')
                      print('1.水龍吟 2.念奴嬌 3.水調歌頭')
                      ans8=int(input('輸入你的答案:'))
                      if ans8 == 3:
                        print('                           ')
                        print('「可惡！」 炸彈犯說著')
                        print('-----------------------------------------------------------------------')
                        print('「最後一位了，請上前。」')
                        print('即使到了最後一個人，炸彈犯還是沒有任何的動搖')
                        print('                         ')
                        print('既然是最後一個人質了，我一定要救下來。」王警探心想著。')
                        print('                         ')
                        print('Q9:蔣宋美齡享壽？')
                        print('1.104 2.79 3.83')
                        ans9=int(input('輸入你的答案:'))
                        if ans9 == 1:
                          print('                           ')
                          print('「呵」 炸彈犯微笑')
                          print('「我真是沒想到．．．」')
                          print('                           ')
                          print('-----------------------------------------------------------------------')
                          print('答完最後一題後，王警探便立刻往頂樓衝了上去')
                          print('卻看到炸彈犯站在頂樓的邊緣，面對著王警官')
                          print('一邊鼓掌一邊開口：')
                          print('「我真的很佩服你的勇氣及毅力，王警探，這是個有趣的體驗，你帶給了我很大的樂趣。」')
                          print('「很可惜，我們這次得先說再見了，未來肯定還會再見面的。」')
                          print('                         ')
                          print('說完，炸彈犯便從頂樓跳了下去')
                          print('王警探急忙的跑道頂樓邊緣')
                          print('卻看到炸彈犯乘著不知道哪裡拿來的滑翔翼，乘著風，用極快的速度飛離')
                          print('王警探只能看著炸彈犯的身影漸漸消失在雲層中，並懊悔自己沒能即時抓住他。')

                          print('                           ')
                          print('-----------------------------------------------------------------------')
                          print("(在這場震驚全國的事件後)")
                          print("(王警探因為成功救出了所有人質，沒有造成任何一個人傷亡，成為了英雄)")
                          print("(受到了全國人民的敬重)")
                          print("(甚至拿到了總統親自頒發的勳章，並升了官，成為了西銘市警察局的局長)")
                          print("(但他有預感，總有一天，他肯定會被迫再次與那名炸彈犯交鋒)")
                          print('                           ')
                          print("The End")
                          print('-----------------------------------------------------------------------')
                        else:
                          print('「喀擦！」 王警探剪下了炸彈線，然而炸彈的警示聲不減反增。')
                          print('噗滋 人質的人頭在王警探面前應聲倒下')
                          print('「完了…」，他又答錯了，王警探抱著絕望的心情看著自己沾滿鮮血的雙手')
                          print('                         ')
                          print('這時，廣播再度響起：')
                          print('                         ')
                          print('「很可惜，王警探，你似乎沒能闖關成功，按照規則，剩下的人質們恐怕也得因為你而犧牲了。」')
                          print('炸彈犯的話還沒講完，大樓內便響起了爆炸聲，王警探只能跪在地上，懊悔著自己所做的決定，以及自己沒能拯救的人命。')
                      else:
                        print('「喀擦！」 王警探剪下了炸彈線，然而炸彈的警示聲不減反增。')
                        print('噗滋 人質的人頭在王警探面前應聲倒下')
                        print('「完了…」，他又答錯了，王警探抱著絕望的心情看著自己沾滿鮮血的雙手')
                        print('                         ')
                        print('這時，廣播再度響起：')
                        print('                         ')
                        print('「很可惜，王警探，你似乎沒能闖關成功，按照規則，剩下的人質們恐怕也得因為你而犧牲了。」')
                        print('炸彈犯的話還沒講完，大樓內便響起了爆炸聲，王警探只能跪在地上，懊悔著自己所做的決定，以及自己沒能拯救的人命。') 
                    else:
                      print('「喀擦！」 王警探剪下了炸彈線，然而炸彈的警示聲不減反增。')
                      print('噗滋 人質的人頭在王警探面前應聲倒下')
                      print('「完了…」，他又答錯了，王警探抱著絕望的心情看著自己沾滿鮮血的雙手')
                      print('                         ')
                      print('這時，廣播再度響起：')
                      print('                         ')
                      print('「很可惜，王警探，你似乎沒能闖關成功，按照規則，剩下的人質們恐怕也得因為你而犧牲了。」')
                      print('炸彈犯的話還沒講完，大樓內便響起了爆炸聲，王警探只能跪在地上，懊悔著自己所做的決定，以及自己沒能拯救的人命。')


                  else:
                    print('「喀擦！」 王警探剪下了炸彈線，然而炸彈的警示聲不減反增。')
                    print('噗滋 人質的人頭在王警探面前應聲倒下')
                    print('「完了…」，他又答錯了，王警探抱著絕望的心情看著自己沾滿鮮血的雙手')
                    print('                         ')
                    print('這時，廣播再度響起：')
                    print('                         ')
                    print('「很可惜，王警探，你似乎沒能闖關成功，按照規則，剩下的人質們恐怕也得因為你而犧牲了。」')
                    print('炸彈犯的話還沒講完，大樓內便響起了爆炸聲，王警探只能跪在地上，懊悔著自己所做的決定，以及自己沒能拯救的人命。')
                else:
                  print('「喀擦！」 王警探剪下了炸彈線，然而炸彈的警示聲不減反增。')
                  print('噗滋 人質的人頭在王警探面前應聲倒下')
                  print('「完了…」，他又答錯了，王警探抱著絕望的心情看著自己沾滿鮮血的雙手')
                  print('                         ')
                  print('這時，廣播再度響起：')
                  print('                         ')
                  print('「很可惜，王警探，你似乎沒能闖關成功，按照規則，剩下的人質們恐怕也得因為你而犧牲了。」')
                  print('炸彈犯的話還沒講完，大樓內便響起了爆炸聲，王警探只能跪在地上，懊悔著自己所做的決定，以及自己沒能拯救的人命。') 
              else:
                print('「喀擦！」 王警探剪下了炸彈線，然而炸彈的警示聲不減反增。')
                print('噗滋 人質的人頭在王警探面前應聲倒下')
                print('「完了…」，他又答錯了，王警探抱著絕望的心情看著自己沾滿鮮血的雙手')
                print('                         ')
                print('這時，廣播再度響起：')
                print('                         ')
                print('「很可惜，王警探，你似乎沒能闖關成功，按照規則，剩下的人質們恐怕也得因為你而犧牲了。」')
                print('炸彈犯的話還沒講完，大樓內便響起了爆炸聲，王警探只能跪在地上，懊悔著自己所做的決定，以及自己沒能拯救的人命。')


            else:
              print('「喀擦！」 王警探剪下了炸彈線，然而炸彈的警示聲不減反增。')
              print('噗滋 人質的人頭在王警探面前應聲倒下')
              print('「完了…」，他又答錯了，王警探抱著絕望的心情看著自己沾滿鮮血的雙手')
              print('                         ')
              print('這時，廣播再度響起：')
              print('                         ')
              print('「很可惜，王警探，你似乎沒能闖關成功，按照規則，剩下的人質們恐怕也得因為你而犧牲了。」')
              print('炸彈犯的話還沒講完，大樓內便響起了爆炸聲，王警探只能跪在地上，懊悔著自己所做的決定，以及自己沒能拯救的人命。')
          else:
            print('「喀擦！」 王警探剪下了炸彈線，然而炸彈的警示聲不減反增。')
            print('噗滋 人質的人頭在王警探面前應聲倒下')
            print('「完了…」，他又答錯了，王警探抱著絕望的心情看著自己沾滿鮮血的雙手')
            print('                         ')
            print('這時，廣播再度響起：')
            print('                         ')
            print('「很可惜，王警探，你似乎沒能闖關成功，按照規則，剩下的人質們恐怕也得因為你而犧牲了。」')
            print('炸彈犯的話還沒講完，大樓內便響起了爆炸聲，王警探只能跪在地上，懊悔著自己所做的決定，以及自己沒能拯救的人命。') 
        else:
          print('「喀擦！」 王警探剪下了炸彈線，然而炸彈的警示聲不減反增。')
          print('噗滋 人質的人頭在王警探面前應聲倒下')
          print('「完了…」，他又答錯了，王警探抱著絕望的心情看著自己沾滿鮮血的雙手')
          print('                         ')
          print('這時，廣播再度響起：')
          print('                         ')
          print('「很可惜，王警探，你似乎沒能闖關成功，按照規則，剩下的人質們恐怕也得因為你而犧牲了。」')
          print('炸彈犯的話還沒講完，大樓內便響起了爆炸聲，王警探只能跪在地上，懊悔著自己所做的決定，以及自己沒能拯救的人命。')


    else:
        print("遊戲結束。")
else:
    print("神秘人士 : 好，這是你自找的。")
    print("(蹦!!!)")
    print("遊戲結束。")
# Out:
# (早上八點，西銘市警察局的王警探已經在工作崗位上。
# (桌上已經堆滿許多待處理案件。)
# 王警探 : 今天依舊忙碌的一天，算了先來想要喝什麼來開啟美好的一天。
# Enter your choice:柯勒
# 王警探 : 好耶!就決定喝 柯勒 了!
# (早上的警局非常忙碌，各警員各司其職。)
# (不知不覺到了中午。)
# 王警探 : 上午處理的事情也太多了吧!快累死了，肚子好餓。
# 王警探 : 中午要吃什麼呢?炒飯還是義大利麵，想一下吃什麼下午比較有精神。
# 午餐吃炒飯還是義大利麵:義大利麵
# 王警探 : 今天這麼累，好好犒賞自己吃點好的!
# (拎拎拎!)
# 王警探 : 唉呀!怎麼這時候剛好有電話進來。
# (王警探不耐煩的接起電話。)
# 王警探: 您好，這裡是西銘市警察局。
# 神秘人士 : 您好，不必知道我是誰，只要知道我在西銘摩天大樓安裝炸彈就好。
# (面對突如其來的告知，王警探一時反應不過來。)
# 王警探 : 怎麼感覺是來亂的?到底要接案還是掛掉電話?
# 請選擇接案或是掛掉電話:接案
# 神秘人士 : 你或許不會相信我說的話，因此我將會引爆第一顆炸彈來證明。
# (蹦!!!)
# (遠方傳來爆炸聲)
# 王警探 : 這...這到底是怎樣?
# 你不用擔心，這顆炸彈是在停車場引爆的，我已經確定停車場裡沒有任何人，但我已經扣押了9名人質，若你不早點趕過來的話，等到大樓裡的炸彈爆炸後，我就不保證這9個人能不能活下來了。
# (這時王警探發現，他就是傳說中的神祕炸彈客。)
# 你想要的到底是什麼!?
# 炸彈客 : 我要你在半小時內單獨來這裡，而且不准穿任何防爆衣，我會在頂樓等你，若你沒有照我的要求，這棟大樓裡的所有人都會沒命。
# 王警探 : 等...等等...
# (炸彈客掛斷電話，不讓王警探有更多的詢問機會。)
# 王警探 : 唉，看來得單刀去了，但怕我會死在那裏，我該穿防爆衣嗎?
# Yes or No:No
# 王警探 : 必須要在半小時內達到大樓，以全程最高速度駕駛為前提，自駕汽車最高可以開到60km/hr，加上等交通號誌時間6分鐘 ; 機車最高可以騎到30km/hr，但機動性高可以鑽小路，可省去12分鐘。
# 請選擇汽車還是機車:汽車
# 遊戲結束。

# %%
print('一進到大樓，你便看到三名人質顫抖著')
print('站在服務台前，他們的脖子上都戴著一條鐵色的項圈，上面有紅光緩緩的在閃爍......')
print('這時，大樓內的廣播響了起來：')
print('                          ')
print('*「那麼，第一位人質請上前。」*')
print('站在最左側的人質走了向前.')
print('是位中年婦女')
print('她用顫抖的聲音哀求著王警探，希望王警探能趕緊讓她脫離恐懼。')
print('                          ')
print('王警探觀察了她的脖子後面')
print('上面寫著一個題目以及三個選項')
print('選項分別代表著紅色、藍色及白色')
print('而項圈上也有這三個顏色的引線')
print('王警探必須選擇正確的顏色剪斷，而機會只有一次。')
print('                          ')
print('Q1:「鱟」在生物學上的分類？')
print('1.節肢動物門 2.腔腸動物門 3.軟體動物門')
ans1=int(input('輸入你的答案:'))
if ans1 == 1:
  print('恭喜你答對了～ 沒想到竟然被你輕鬆答對')
  print('「讓我們歡迎第二名人質。」廣播聲再次響起。')
  print('                           ')
  print('-----------------------------------------------------------------------')
  print('第二名人質拖著有氣無力的腳步走向王警探')
  print('「拜託你了。」他望向王警探的眼神中沒有任何的希望。')
  print('                           ')
  print('Q2:日本名著的明治神宮，位於？')
  print('1.山形 2.東京 3.大阪')
  ans2=int(input('輸入你的答案:'))
  if ans2 == 2:
    print('竟然又被你猜對了... 接下來可沒那麼容易')
    print('                           ')
    print('「接下來，是第三名人質。」廣播聲再次響起。')
    print('第三名人質是位壯年男子')
    print('他拍了拍王警探的背，用激勵的眼神看著王警探')
    print('「我相信你。」短短的四個字，給了王警探巨大的信心。')
    print('                           ')
    print('Q3:歌劇「費加洛婚禮」為何者作品？')
    print('1.莫札特 2.小柴可夫斯基 3.普契尼')
    ans3=int(input('輸入你的答案:'))
    if ans3 == 1:
      print('                           ')
      print('呵呵呵 真有趣.....')
    else:
      print('「喀擦！」 王警探剪下了炸彈線，然而炸彈的警示聲不減反增。')
      print('噗滋 人質的人頭在王警探面前應聲倒下')
      print('「完了…」，他又答錯了，王警探抱著絕望的心情看著自己沾滿鮮血的雙手')
      print('                         ')
      print('這時，廣播再度響起：')
      print('                         ')
      print('「很可惜，王警探，你似乎沒能闖關成功，按照規則，剩下的人質們恐怕也得因為你而犧牲了。」')
      print('炸彈犯的話還沒講完，大樓內便響起了爆炸聲，王警探只能跪在地上，懊悔著自己所做的決定，以及自己沒能拯救的人命。')
  else:
    print('「喀擦！」 王警探剪下了炸彈線，然而炸彈的警示聲不減反增。')
    print('噗滋 人質的人頭在王警探面前應聲倒下')
    print('「完了…」，他又答錯了，王警探抱著絕望的心情看著自己沾滿鮮血的雙手')
    print('                         ')
    print('這時，廣播再度響起：')
    print('                         ')
    print('「很可惜，王警探，你似乎沒能闖關成功，按照規則，剩下的人質們恐怕也得因為你而犧牲了。」')
    print('炸彈犯的話還沒講完，大樓內便響起了爆炸聲，王警探只能跪在地上，懊悔著自己所做的決定，以及自己沒能拯救的人命。') 
else:
  print('「喀擦！」 王警探剪下了炸彈線，然而炸彈的警示聲不減反增。')
  print('噗滋 人質的人頭在王警探面前應聲倒下')
  print('「完了…」，他又答錯了，王警探抱著絕望的心情看著自己沾滿鮮血的雙手')
  print('                         ')
  print('這時，廣播再度響起：')
  print('                         ')
  print('「很可惜，王警探，你似乎沒能闖關成功，按照規則，剩下的人質們恐怕也得因為你而犧牲了。」')
  print('炸彈犯的話還沒講完，大樓內便響起了爆炸聲，王警探只能跪在地上，懊悔著自己所做的決定，以及自己沒能拯救的人命。')
# Out:
# 一進到大樓，你便看到三名人質顫抖著
# 站在服務台前，他們的脖子上都戴著一條鐵色的項圈，上面有紅光緩緩的在閃爍......
# 這時，大樓內的廣播響了起來：
#
# *「那麼，第一位人質請上前。」*
# 站在最左側的人質走了向前.
# 是位中年婦女
# 她用顫抖的聲音哀求著王警探，希望王警探能趕緊讓她脫離恐懼。
#
# 王警探觀察了她的脖子後面
# 上面寫著一個題目以及三個選項
# 選項分別代表著紅色、藍色及白色
# 而項圈上也有這三個顏色的引線
# 王警探必須選擇正確的顏色剪斷，而機會只有一次。
#
# Q1:「鱟」在生物學上的分類？
# 1.節肢動物門 2.腔腸動物門 3.軟體動物門
# 輸入你的答案:1
# 恭喜你答對了～ 沒想到竟然被你輕鬆答對
# 「讓我們歡迎第二名人質。」廣播聲再次響起。
#
# -----------------------------------------------------------------------
# 第二名人質拖著有氣無力的腳步走向王警探
# 「拜託你了。」他望向王警探的眼神中沒有任何的希望。
#
# Q2:日本名著的明治神宮，位於？
# 1.山形 2.東京 3.大阪
# 輸入你的答案:2
# 竟然又被你猜對了... 接下來可沒那麼容易
#
# 「接下來，是第三名人質。」廣播聲再次響起。
# 第三名人質是位壯年男子
# 他拍了拍王警探的背，用激勵的眼神看著王警探
# 「我相信你。」短短的四個字，給了王警探巨大的信心。
#
# Q3:歌劇「費加洛婚禮」為何者作品？
# 1.莫札特 2.小柴可夫斯基 3.普契尼
# 輸入你的答案:1
#
# 呵呵呵 真有趣.....

# %%
#一樓三名人質結束後
print('「呼….」王警探擦了擦額頭的冷汗，稍微喘了口氣穩定下自己的心情')
print('這時，王警探的手機又響了起來：')
print('                           ')
print('「恭喜你完成了一樓的關卡，記得，你還有許多難關」')
print('「你會選擇繼續上樓尋找我，並想辦法救出剩下的人呢？」')
print('「還是就此罷手，帶著這幾名人質離開？」')
print('                           ')
print('-----------------------------------------------------------------------')
print('1.繼續上樓 2.只帶著一樓的人質離開')
go=int(input('你的選擇是：'))
if go== 1:
  print('                           ')
  print('王警探並沒有做太久的考慮')
  print('他將人質安置在一樓後，便筆直的朝電梯走去')
  print('他心知肚明，若他在這裡選擇逃跑的話，他會後悔一輩子。')
  print('                           ')
  print('                           ')
else:
  print('                           ')
  print('王警探閉起眼睛，考慮了將近一分鐘')
  print('他最後仍沒能鼓起勇氣，以自己的性命為賭注，去拯救那些跟他沒有任何關係的陌生人')
  print('                           ')
  print('王警探帶著目前成功救出的人質，離開了大樓......')
  print('                           ')
  print('離開大樓沒多遠，便聽見大樓內傳來爆炸聲')
  print('王警探抱著頭蹲了下來，懊悔自己的無能。')
  print('                           ')
  print('                           ')
  print('---GAME OVER---')
# Out:
# 「呼….」王警探擦了擦額頭的冷汗，稍微喘了口氣穩定下自己的心情
# 這時，王警探的手機又響了起來：
#
# 「恭喜你完成了一樓的關卡，記得，你還有許多難關」
# 「你會選擇繼續上樓尋找我，並想辦法救出剩下的人呢？」
# 「還是就此罷手，帶著這幾名人質離開？」
#
# -----------------------------------------------------------------------
# 1.繼續上樓 2.只帶著一樓的人質離開
# 你的選擇是：1
#
# 王警探並沒有做太久的考慮
# 他將人質安置在一樓後，便筆直的朝電梯走去
# 他心知肚明，若他在這裡選擇逃跑的話，他會後悔一輩子。

# %%
#到達40樓後
print('王警探乘坐著電梯來到了40樓')
print('電梯門一開，他便看到了跟一樓相似的場景')
print('                           ')
print('三名無辜的人質、以及他們脖子上那危險的殺人工具。')
print('                           ')
print('「歡迎來到40樓，王警探，我佩服你的勇氣。」')
print('廣播裡再度傳來炸彈犯那冷靜且無情的聲音。')
print('                           ')
print('-----------------------------------------------------------------------')
print('「第四名人質，請上前。」')
print('                           ')
print('宛如被宣告死刑一般，站在最左邊的大樓職員露出了驚恐的表情，走上前面對自己的生死')
print('他萬萬沒想到，他跟平常一樣的來這裡上班，卻會碰上這種事。')
print('                           ')
print('Q4:已知果蠅體細胞內有四對染色體，則其卵子中的染色體數？')
print('1.四對染色體 2.兩對染色體 3.兩條不成對染色體')
ans4=int(input('輸入你的答案:'))
if ans4 == 2:
  print('                           ')
  print('「又對了...」')
  print('「一開始選上你真是正確的選擇啊  太有趣了....」')
  print('                           ')
  print('-----------------------------------------------------------------------')
  print('「輪到你了，小朋友。」廣播裡的聲音沒有任何的改變')
  print('                           ')
  print('第五名人質是一位小男孩')
  print('目測年齡大概只有10歲左右')
  print('但犯人並不會因此放過他。')
  print('                           ')
  print('但小男孩卻因為害怕，沒有任何的行動')
  print('王警探只好走到小男孩的背後來看題目，並抓著小男孩的手，給小男孩勇氣。')
  print('                           ')
  print('                           ')
  print('Q5:唐朝詩人，善有長恨歌描寫楊貴妃生平的是？')
  print('1.張繼 2.杜光庭 3.白居易')
  ans5=int(input('輸入你的答案:'))
  if ans5 == 3:
    print('                           ')
    print('「呵......」')
    print('                           ')
    print('-----------------------------------------------------------------------')
    print('第六名人質對王警探的壓力是目前為止最大的')
    print('                           ')
    print('因為第六名人質是名孕婦')
    print('                           ')
    print('代表著王警探這一次的選擇，將背負著兩條人命。')
    print('                           ')
    print('孕婦走向王警探時，並沒有說任何話')
    print('甚至連眼神都沒有交會')
    print('孕婦只是轉過身，撩起頭髮，讓王警探看清楚題目。')
    print('                           ')
    print('Q6:創立坐標幾何的人是誰？')
    print('1.巴比 2.笛卡兒 3.畢達哥拉斯')
    ans6=int(input('輸入你的答案:'))
    if ans6 == 2:
      print('                           ')
      print('「哈哈哈哈哈.哈..哈.哈....」  犯人此時漸漸感受到不妙')
      print('                           ')
    else:
      print('「喀擦！」 王警探剪下了炸彈線，然而炸彈的警示聲不減反增。')
      print('噗滋 人質的人頭在王警探面前應聲倒下')
      print('「完了…」，他又答錯了，王警探抱著絕望的心情看著自己沾滿鮮血的雙手')
      print('                         ')
      print('這時，廣播再度響起：')
      print('                         ')
      print('「很可惜，王警探，你似乎沒能闖關成功，按照規則，剩下的人質們恐怕也得因為你而犧牲了。」')
      print('炸彈犯的話還沒講完，大樓內便響起了爆炸聲，王警探只能跪在地上，懊悔著自己所做的決定，以及自己沒能拯救的人命。')
  else:
    print('「喀擦！」 王警探剪下了炸彈線，然而炸彈的警示聲不減反增。')
    print('噗滋 人質的人頭在王警探面前應聲倒下')
    print('「完了…」，他又答錯了，王警探抱著絕望的心情看著自己沾滿鮮血的雙手')
    print('                         ')
    print('這時，廣播再度響起：')
    print('                         ')
    print('「很可惜，王警探，你似乎沒能闖關成功，按照規則，剩下的人質們恐怕也得因為你而犧牲了。」')
    print('炸彈犯的話還沒講完，大樓內便響起了爆炸聲，王警探只能跪在地上，懊悔著自己所做的決定，以及自己沒能拯救的人命。') 
else:
  print('「喀擦！」 王警探剪下了炸彈線，然而炸彈的警示聲不減反增。')
  print('噗滋 人質的人頭在王警探面前應聲倒下')
  print('「完了…」，他又答錯了，王警探抱著絕望的心情看著自己沾滿鮮血的雙手')
  print('                         ')
  print('這時，廣播再度響起：')
  print('                         ')
  print('「很可惜，王警探，你似乎沒能闖關成功，按照規則，剩下的人質們恐怕也得因為你而犧牲了。」')
  print('炸彈犯的話還沒講完，大樓內便響起了爆炸聲，王警探只能跪在地上，懊悔著自己所做的決定，以及自己沒能拯救的人命。')
# Out:
# 王警探乘坐著電梯來到了40樓
# 電梯門一開，他便看到了跟一樓相似的場景
#
# 三名無辜的人質、以及他們脖子上那危險的殺人工具。
#
# 「歡迎來到40樓，王警探，我佩服你的勇氣。」
# 廣播裡再度傳來炸彈犯那冷靜且無情的聲音。
#
# -----------------------------------------------------------------------
# 「第四名人質，請上前。」
#
# 宛如被宣告死刑一般，站在最左邊的大樓職員露出了驚恐的表情，走上前面對自己的生死
# 他萬萬沒想到，他跟平常一樣的來這裡上班，卻會碰上這種事。
#
# Q4:已知果蠅體細胞內有四對染色體，則其卵子中的染色體數？
# 1.四對染色體 2.兩對染色體 3.兩條不成對染色體
# 輸入你的答案:2
#
# 「又對了...」
# 「一開始選上你真是正確的選擇啊  太有趣了....」
#
# -----------------------------------------------------------------------
# 「輪到你了，小朋友。」廣播裡的聲音沒有任何的改變
#
# 第五名人質是一位小男孩
# 目測年齡大概只有10歲左右
# 但犯人並不會因此放過他。
#
# 但小男孩卻因為害怕，沒有任何的行動
# 王警探只好走到小男孩的背後來看題目，並抓著小男孩的手，給小男孩勇氣。
#
#
# Q5:唐朝詩人，善有長恨歌描寫楊貴妃生平的是？
# 1.張繼 2.杜光庭 3.白居易
# 輸入你的答案:3
#
# 「呵......」
#
# -----------------------------------------------------------------------
# 第六名人質對王警探的壓力是目前為止最大的
#
# 因為第六名人質是名孕婦
#
# 代表著王警探這一次的選擇，將背負著兩條人命。
#
# 孕婦走向王警探時，並沒有說任何話
# 甚至連眼神都沒有交會
# 孕婦只是轉過身，撩起頭髮，讓王警探看清楚題目。
#
# Q6:創立坐標幾何的人是誰？
# 1.巴比 2.笛卡兒 3.畢達哥拉斯
# 輸入你的答案:2
#
# 「哈哈哈哈哈.哈..哈.哈....」  犯人此時漸漸感受到不妙

# %%
#40樓三名人質結束後

print('王警探在答完第六題後，跌坐了下來')
print('                         ')
print('每一次自己的答題都攸關某個人的生死，這對他的心理壓力實在太大')
print('                         ')
print('但似乎是不想給王警探休息時間')
print('王警探的手機立刻響了起來')
print('果不其然，打來的仍是犯人：')
print('                         ')
print('「王警探，恭喜你完成了第二階段」')
print('「我仍會給你選擇機會，你只要繼續往上，來到頂樓就可以找到我」')
print('「但還有最後三題要答，或者你也可以選擇離開，帶著你救到的人們逃跑」')
print('「那麼，你的選擇是？」')
print('                         ')
print('-----------------------------------------------------------------------')
print('                         ')
print('1.繼續上樓 2.只帶著一樓的人質離開')
go2=int(input('你的選擇是：'))
if go2== 1:
  print('                           ')
  print('「都已經來到這裡了，我怎麼可能就此罷休！」王警探怒吼著')
  print('似乎是在對犯人說話，又好像是在激烈自己，給自己繼續往上的動力')
  print('休息不到一分鐘，王警探便從地板上跳了起來，繼續往上邁進。')
  print('                           ')
  print('                           ')
else:
  print('                           ')
  print('王警探閉起眼睛，考慮了將近一分鐘')
  print('他最後仍沒能鼓起勇氣，以自己的性命為賭注，去拯救那些跟他沒有任何關係的陌生人')
  print('                           ')
  print('王警探帶著目前成功救出的人質，離開了大樓......')
  print('                           ')
  print('離開大樓沒多遠，便聽見大樓內傳來爆炸聲')
  print('王警探抱著頭蹲了下來，懊悔自己的無能。')
  print('                           ')
  print('                           ')
  print('---GAME OVER---')
# Out:
# 王警探在答完第六題後，跌坐了下來
#
# 每一次自己的答題都攸關某個人的生死，這對他的心理壓力實在太大
#
# 但似乎是不想給王警探休息時間
# 王警探的手機立刻響了起來
# 果不其然，打來的仍是犯人：
#
# 「王警探，恭喜你完成了第二階段」
# 「我仍會給你選擇機會，你只要繼續往上，來到頂樓就可以找到我」
# 「但還有最後三題要答，或者你也可以選擇離開，帶著你救到的人們逃跑」
# 「那麼，你的選擇是？」
#
# -----------------------------------------------------------------------
#
# 1.繼續上樓 2.只帶著一樓的人質離開
# 你的選擇是：1
#
# 「都已經來到這裡了，我怎麼可能就此罷休！」王警探怒吼著
# 似乎是在對犯人說話，又好像是在激烈自己，給自己繼續往上的動力
# 休息不到一分鐘，王警探便從地板上跳了起來，繼續往上邁進。

# %%
#繼續往上後
print('西銘大樓的頂樓並沒有辦法直接搭電梯上去，而是必須走樓梯')
print('因此王警探搭到電梯能到的最高樓後，便往樓梯間奔去')
print('                           ')
print('往上沒多久，在到達頂樓前的樓梯上遇到了三名人質')
print('而人質的背後，就是炸彈犯。')
print('                           ')
print('炸彈犯穿的西裝筆挺，戴著面具，整個人的氣質就跟他的聲音一樣：彬彬有禮，卻又令人不寒而慄。')
print('                           ')
print('-----------------------------------------------------------------------')
print('                           ')
print('「很高興見到你，王警探，總算不用透過廣播或電話給你溝通了。」炸彈犯笑著說。')
print('                           ')
print('王警探恨不得直接衝上去給對方一拳')
print('但對方手上還有三名人質，王警探只能忍住怒氣，繼續遵照對方的規則走。')
print('                           ')
print('-----------------------------------------------------------------------')
print('沒有等炸彈犯催促，第七名人質便自動走了上前')
print('是位目測四十歲左右的女性')
print('胸前的名牌表示了她是這棟大樓的主管之一。')
print('                           ')
print('Q7:俗稱的安息香油是？')
print('1.乙烯 2.甲烷 3.苯')
ans7=int(input('輸入你的答案:'))
if ans7 == 3:
  print('                           ')
  print('「什...什..什麼！」')
  print('                           ')
  print('-----------------------------------------------------------------------')
  print('第八名人質是名小混混')
  print('用面帶不屑的眼神撇了一眼炸彈犯後')
  print('搖晃著身體，慢慢的走向王警探')
  print('但王警探看得出來，他只是在逞兇鬥狠。')
  print('                         ')
  print('Q8:「但願人長久，千里共嬋娟。」出自蘇軾的何首作品？')
  print('1.水龍吟 2.念奴嬌 3.水調歌頭')
  ans8=int(input('輸入你的答案:'))
  if ans8 == 3:
    print('                           ')
    print('「可惡！」 炸彈犯說著')
    print('-----------------------------------------------------------------------')
    print('「最後一位了，請上前。」')
    print('即使到了最後一個人，炸彈犯還是沒有任何的動搖')
    print('                         ')
    print('既然是最後一個人質了，我一定要救下來。」王警探心想著。')
    print('                         ')
    print('Q9:蔣宋美齡享壽？')
    print('1.104 2.79 3.83')
    ans9=int(input('輸入你的答案:'))
    if ans9 == 1:
      print('                           ')
      print('「呵」 炸彈犯微笑')
      print('「我真是沒想到．．．」')
      print('                           ')
      print('-----------------------------------------------------------------------')
      print('答完最後一題後，王警探便立刻往頂樓衝了上去')
      print('卻看到炸彈犯站在頂樓的邊緣，面對著王警官')
      print('一邊鼓掌一邊開口：')
      print('「我真的很佩服你的勇氣及毅力，王警探，這是個有趣的體驗，你帶給了我很大的樂趣。」')
      print('「很可惜，我們這次得先說再見了，未來肯定還會再見面的。」')
      print('                         ')
      print('說完，炸彈犯便從頂樓跳了下去')
      print('王警探急忙的跑道頂樓邊緣')
      print('卻看到炸彈犯乘著不知道哪裡拿來的滑翔翼，乘著風，用極快的速度飛離')
      print('王警探只能看著炸彈犯的身影漸漸消失在雲層中，並懊悔自己沒能即時抓住他。')
    else:
      print('「喀擦！」 王警探剪下了炸彈線，然而炸彈的警示聲不減反增。')
      print('噗滋 人質的人頭在王警探面前應聲倒下')
      print('「完了…」，他又答錯了，王警探抱著絕望的心情看著自己沾滿鮮血的雙手')
      print('                         ')
      print('這時，廣播再度響起：')
      print('                         ')
      print('「很可惜，王警探，你似乎沒能闖關成功，按照規則，剩下的人質們恐怕也得因為你而犧牲了。」')
      print('炸彈犯的話還沒講完，大樓內便響起了爆炸聲，王警探只能跪在地上，懊悔著自己所做的決定，以及自己沒能拯救的人命。')
  else:
    print('「喀擦！」 王警探剪下了炸彈線，然而炸彈的警示聲不減反增。')
    print('噗滋 人質的人頭在王警探面前應聲倒下')
    print('「完了…」，他又答錯了，王警探抱著絕望的心情看著自己沾滿鮮血的雙手')
    print('                         ')
    print('這時，廣播再度響起：')
    print('                         ')
    print('「很可惜，王警探，你似乎沒能闖關成功，按照規則，剩下的人質們恐怕也得因為你而犧牲了。」')
    print('炸彈犯的話還沒講完，大樓內便響起了爆炸聲，王警探只能跪在地上，懊悔著自己所做的決定，以及自己沒能拯救的人命。') 
else:
  print('「喀擦！」 王警探剪下了炸彈線，然而炸彈的警示聲不減反增。')
  print('噗滋 人質的人頭在王警探面前應聲倒下')
  print('「完了…」，他又答錯了，王警探抱著絕望的心情看著自己沾滿鮮血的雙手')
  print('                         ')
  print('這時，廣播再度響起：')
  print('                         ')
  print('「很可惜，王警探，你似乎沒能闖關成功，按照規則，剩下的人質們恐怕也得因為你而犧牲了。」')
  print('炸彈犯的話還沒講完，大樓內便響起了爆炸聲，王警探只能跪在地上，懊悔著自己所做的決定，以及自己沒能拯救的人命。')
# Out:
# 西銘大樓的頂樓並沒有辦法直接搭電梯上去，而是必須走樓梯
# 因此王警探搭到電梯能到的最高樓後，便往樓梯間奔去
#
# 往上沒多久，在到達頂樓前的樓梯上遇到了三名人質
# 而人質的背後，就是炸彈犯。
#
# 炸彈犯穿的西裝筆挺，戴著面具，整個人的氣質就跟他的聲音一樣：彬彬有禮，卻又令人不寒而慄。
#
# -----------------------------------------------------------------------
#
# 「很高興見到你，王警探，總算不用透過廣播或電話給你溝通了。」炸彈犯笑著說。
#
# 王警探恨不得直接衝上去給對方一拳
# 但對方手上還有三名人質，王警探只能忍住怒氣，繼續遵照對方的規則走。
#
# -----------------------------------------------------------------------
# 沒有等炸彈犯催促，第七名人質便自動走了上前
# 是位目測四十歲左右的女性
# 胸前的名牌表示了她是這棟大樓的主管之一。
#
# Q7:俗稱的安息香油是？
# 1.乙烯 2.甲烷 3.苯
# 輸入你的答案:3
#
# 「什...什..什麼！」
#
# -----------------------------------------------------------------------
# 第八名人質是名小混混
# 用面帶不屑的眼神撇了一眼炸彈犯後
# 搖晃著身體，慢慢的走向王警探
# 但王警探看得出來，他只是在逞兇鬥狠。
#
# Q8:「但願人長久，千里共嬋娟。」出自蘇軾的何首作品？
# 1.水龍吟 2.念奴嬌 3.水調歌頭
# 輸入你的答案:3
#
# 「可惡！」 炸彈犯說著
# -----------------------------------------------------------------------
# 「最後一位了，請上前。」
# 即使到了最後一個人，炸彈犯還是沒有任何的動搖
#
# 既然是最後一個人質了，我一定要救下來。」王警探心想著。
#
# Q9:蔣宋美齡享壽？
# 1.104 2.79 3.83
# 輸入你的答案:1
#
# 「呵」 炸彈犯微笑
# 「我真是沒想到．．．」
#
# ...

# %% [markdown]
# #全救結局
#
# 在這場震驚全國的事件後
# >
# 王警探因為成功救出了所有人質，沒有造成任何一個人傷亡，成為了英雄
# >
# 受到了全國人民的敬重
# >
# 甚至拿到了總統親自頒發的勳章，並升了官，成為了西銘市警察局的局長。
# >
# 但他有預感，總有一天，他肯定會被迫再次與那名炸彈犯交鋒。
# >
# >
# >
# **---THE END---**

# %% [markdown]
# 職責分配:
#
# 劇情和文稿:吳宣翰
# 程式編寫和修正:王政善、李珈如
